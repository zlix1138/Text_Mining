# %%
from pathlib import Path

print("현재 작업 폴더:", Path.cwd())

required_paths = [
    Path("youth_migration.csv"),
    Path("youth_policies_categorized.csv"),
    Path("final_results"),
    Path("final_results/01_region_policy_supply_score/region_policy_supply_score_rank.csv"),
    Path("final_results/02_region_policy_gap_score/region_policy_gap_rank.csv"),
]

for p in required_paths:
    print(p, "→", p.exists())
# Out:
# 현재 작업 폴더: C:\Users\yong\Desktop\TM\tm2\textmining_solo_policy_project\textmining_solo_policy_project
# youth_migration.csv → True
# youth_policies_categorized.csv → True
# final_results → True
# final_results\01_region_policy_supply_score\region_policy_supply_score_rank.csv → True
# final_results\02_region_policy_gap_score\region_policy_gap_rank.csv → True
